# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pandas_profiling
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', None)

# %%
#df = pd.read_csv('/gdrive/My Drive/InsighTD-AnalisisColombia/EASE_Data4RQ3_4Jupyter.csv', sep="|", index_col=False)
df = pd.read_csv('Data_RQ2_Heatmap.csv', sep=";", index_col=False)
df.columns.tolist()
# Out:
# ['CAUSES', 'REPAYMENTS', 'FREQ']

# %%
df.head(20)
# Out:
#                                           CAUSES  \
# 0   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 1   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 2   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 3   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 4   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 5   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 6   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 7   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 8   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 9   10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 10  10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 11  10. LACK OF WELL DEFINED PROC. (Paid: 23.7%)
# 12                     1. DEADLINE (Paid: 40.4%)
# 13                     1. DEADLINE (Paid: 40.4%)
# 14                     1. DEADLINE (Paid: 40.4%)
# 15                     1. DEADLINE (Paid: 40.4%)
# 16                     1. DEADLINE (Paid: 40.4%)
# 17                     1. DEADLINE (Paid: 40.4%)
# ...

# %%
#dfA = df[df['ROLE']=='ARCHITECT']
dfA = df

# %%
dfA.replace(to_replace ="IMPROVEMENT IN REQUIREMENT ELICITATION", value ="IMPROV. REQUIREM. ELICIT.", inplace=True) 
dfA.replace(to_replace ="TECHNOLOGY INDEPENDENT IMPLEMENTATION", value ="TECH. INDEPEND. IMPL.", inplace=True) 
dfA.replace(to_replace ="TECHNOLOGY/TOOL/PLATFORM CHANGE", value ="TECH/TOOL/PLATF. CHANGE", inplace=True) 
dfA.replace(to_replace ="HIRING QUALIFIED PROFESSIONALS", value ="HIRING QUAL. PROs.", inplace=True) 
dfA.replace(to_replace ="APPROACHING THE CLIENT WITH THE DEVELOPMENT TEAM", value ="APPROACH CLIENT WITH DEV. TEAM", inplace=True) 
dfA.replace(to_replace ="CONTINUOUS IMPROVEMENT OF APPLICATIONS", value ="CONTINUOUS IMPROV. OF APPS", inplace=True) 
dfA.replace(to_replace ="DEFINITION OF SPRINTS FOR THE PAYMENT OF DT", value ="SPRINTS FOR TD PAYMENT", inplace=True) 
dfA.replace(to_replace ="ORGANISATION OF THE PROJECT REPOSITORY", value ="ORGANISATION OF PROJ. REPO", inplace=True) 
dfA.replace(to_replace ="STARTING THE PROJECT FROM SCRATCH", value ="STARTING PROJ. FROM SCRATCH", inplace=True)

# %%
df1 = dfA.pivot("CAUSES", "REPAYMENTS", "FREQ")

plt.figure(figsize = (15,4))

sns.set(font_scale=1.2)
ax = sns.heatmap(df1, vmin=0, vmax=12, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD REPAYMENT\nBY SOFTWARE ARCHITECTS\n", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.0, 0.0)
