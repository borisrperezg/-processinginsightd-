# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pandas_profiling
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('Data_RQ2_Heatmap.csv', sep="|", index_col=False)
df.columns.tolist()
# Out:
# ['CAUSES', 'PAYMENTPRACTICES', 'FREQ']

# %%
df.head(20)
# Out:
#                           CAUSES                PAYMENTPRACTICES  FREQ
# 0   1st - DEADLINE (Paid: 40.4%)      ADOPTION OF GOOD PRACTICES     4
# 1   1st - DEADLINE (Paid: 40.4%)           ARCHITECTURAL CHANGES     2
# 2   1st - DEADLINE (Paid: 40.4%)               BACKLOG INCLUSION     1
# 3   1st - DEADLINE (Paid: 40.4%)                           CI/CD     1
# 4   1st - DEADLINE (Paid: 40.4%)                  CODE REVIEWING     2
# 5   1st - DEADLINE (Paid: 40.4%)  DEF. OF SPRINTS FOR TD PAYMENT     3
# 6   1st - DEADLINE (Paid: 40.4%)                          DEVOPS     1
# 7   1st - DEADLINE (Paid: 40.4%)  HIRING QUALIFIED PROFESSIONALS     1
# 8   1st - DEADLINE (Paid: 40.4%)                  IMPROVE DESIGN     5
# 9   1st - DEADLINE (Paid: 40.4%)           IMPROVE DOCUMENTATION     2
# 10  1st - DEADLINE (Paid: 40.4%)                 IMPROVE TESTING     8
# 11  1st - DEADLINE (Paid: 40.4%)     IMPROV. REQUIREM. ELICITAT.     2
# 12  1st - DEADLINE (Paid: 40.4%)              MANAGEMENT ACTIONS     2
# 13  1st - DEADLINE (Paid: 40.4%)                  PRIORITIZATION     1
# 14  1st - DEADLINE (Paid: 40.4%)            PROJECT SCOPE CHANGE     1
# 15  1st - DEADLINE (Paid: 40.4%)                     REFACTORING    22
# 16  1st - DEADLINE (Paid: 40.4%)            REPAYMENT ACTIVITIES     5
# 17  1st - DEADLINE (Paid: 40.4%)   RESTORE LOST DATA FROM BACKUP     1
# 18  1st - DEADLINE (Paid: 40.4%)                    SIDE PROJECT     1
# 19  1st - DEADLINE (Paid: 40.4%)    SWITCHING SOFTWARE SOLUTIONS     1

# %%
df1 = df.pivot("CAUSES", "PAYMENTPRACTICES", "FREQ")

plt.figure(figsize = (15,4))

ax = sns.heatmap(df1, vmin=0, vmax=23, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD PAYMENT\n", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.0, 0.0)
